# %% [markdown]
# # Explore imaging data

# %% [markdown]
# A representative set of images from our histology and RNAscope datasets have been made available to view interactively. Here we show how to load these images in a Jupyter notebook using [vitessce-python](https://vitessce.github.io/vitessce-python/). They are also available via the Shiny App at [https://crukci.shinyapps.io/scrabbit-shiny/](https://crukci.shinyapps.io/scrabbit-shiny/).

# %%
from vitessce import (
    VitessceConfig,
    Component as cm,
    CoordinationType as ct,
    OmeTiffWrapper,
    MultiImageWrapper,
)

import pandas as pd

# Location of the OME-TIF images
IMAGING_URL = "https://content.cruk.cam.ac.uk/jmlab/RabbitGastrulation2022/scrabbit-web/imaging/"
IMAGING_META = pd.read_csv(IMAGING_URL + "ome-tiff-metadata.csv")
IMAGING_META.index.name = "ID"

# %% [markdown]
# The set of images available to display are listed in a metdata csv file. The `IMAGING_META` dataframe can be used to select images of interest based on the developmental stage, sectioning plane and type of imaging performed (histology or RNAscope).

# %%
IMAGING_META
# Out:
#                                               Dataset Stage   Embryo  \
# ID
# 0                           GD7_1909-19_Transverse_HE   GD7  1909-19
# 1   GD7_1909-19_Transverse_RNAscope_TFAP2C-POU5F1-...   GD7  1909-19
# 2                             GD7_6902-19_Sagittal_HE   GD7  6902-19
# 3                           GD7_6904-19_Transverse_HE   GD7  6904-19
# 4                           GD8_6983-18_Transverse_HE   GD8  6983-18
# 5                           GD8_6983-18_Transverse_HE   GD8  6983-18
# 6                           GD8_7350-19_Transverse_HE   GD8  7350-19
# 7   GD8_7350-19_Transverse_RNAscope_TFAP2C-POU5F1-...   GD8  7350-19
# 8                              GD9_1034-19_Coronal_HE   GD9  1034-19
# 9       GD9_1034-19_Coronal_RNAscope_CDH5-RUNX1-AHNAK   GD9  1034-19
# 10      GD9_1034-19_Coronal_RNAscope_CDH5-RUNX1-AHNAK   GD9  1034-19
# 11                            GD9_7029-18_Sagittal_HE   GD9  7029-18
#
#          Plane       Type                Probes  Series  \
# ID
# 0   Transverse  Histology                   NaN      29
# 1   Transverse   RNAscope  TFAP2C-POU5F1-NANOS3      14
# 2     Sagittal  Histology                   NaN      16
# 3   Transverse  Histology                   NaN      16
# 4   Transverse  Histology                   NaN      16
# 5   Transverse  Histology                   NaN      16
# 6   Transverse  Histology                   NaN      15
# 7   Transverse   RNAscope  TFAP2C-POU5F1-NANOS3      21
# 8      Coronal  Histology                   NaN      29
# 9      Coronal   RNAscope      CDH5-RUNX1-AHNAK      13
# 10     Coronal   RNAscope      CDH5-RUNX1-AHNAK      13
# 11    Sagittal  Histology                   NaN      16
#
#                                                 Image
# ID
# 0   21238-937_Sl076_e7_1909-19_Rabbit_Foetus_sl051...
# 1   21187-678_Sl012_1909-19_Rabbit_Foetus_sl052_Oc...
# 2                 21187-556_6902-19_sl091_HE_series16
# 3                 21187-556_6904-19_sl121_HE_series16
# 4                 21187-522_6983-18_sl081_HE_series16
# 5                 21187-522_6983-18_sl091_HE_series16
# 6   21238-937_Sl094_e8_7350-19_Rabbit_Foetus_sl041...
# 7   21187-678_Sl008_7350-19_Rabbit_Foetus_sl102_Oc...
# 8   21238-937_Sl165_e9_1034-19_Rabbit_Foetus_sl126...
# 9   21187-677_Sl007_1034-19_Rabbit_Foetus_sl067_Oc...
# 10  21187-677_Sl013_1034-19_Rabbit_Foetus_sl127_Oc...
# 11                21187-522_7029-18_sl060_HE_series16

# %% [markdown]
# We can use the ID value to specify an image to load with Vitessce.

# %%
image_wrappers = [OmeTiffWrapper(img_url=IMAGING_URL + row["Dataset"] + "/" + row["Image"] + ".ome.tif", 
               offsets_url = IMAGING_URL + row["Dataset"] + "/" + row["Image"] + ".offsets.json") for index, row in IMAGING_META.iterrows()]

def viewImageDataset(image_id = 0):
    vc = VitessceConfig(name='Rabbit OME-TIF images', 
                        description='Vitessce widget for viewing Ton et al. 2022 histology and RNAscope images.')
    dataset = vc.add_dataset(name='Ton et al. 2022').add_object(
            MultiImageWrapper(
                image_wrappers=image_wrappers[(image_id):(image_id+1)],
                use_physical_size_scaling=True,
             )
            )
    spatial = vc.add_view(cm.SPATIAL, dataset=dataset)
    lc = vc.add_view(cm.LAYER_CONTROLLER, dataset=dataset).set_props(disableChannelsIfRgbDetected=True)
    vc.layout(spatial | (lc ));


    vw = vc.widget()
    return(vw)

# %%
viewImageDataset(9)
# Out:
# VitessceWidget(config={'version': '1.0.7', 'name': 'Rabbit OME-TIF images', 'description': 'Testing OME-TIF im…
